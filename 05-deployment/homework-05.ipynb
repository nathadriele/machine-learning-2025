# %% [markdown]
# ## Deployment

# %%
# !pip install uv
# Out:
# Collecting uv
#   Downloading uv-0.9.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.9.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 38.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: uv
# Successfully installed uv-0.9.7
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !uv --version
# Out:
# uv 0.9.7

# %%
# !uv add 'scikit-learn==1.6.1'
# Out:
# Using CPython 3.14.0
# Creating virtual environment at: /workspaces/machine-learning-2025/.venv
# Resolved 50 packages in 291ms
# ⠦ Preparing packages... (18/19)

# %% [markdown]
# ### Models

# %%
# !wget https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
